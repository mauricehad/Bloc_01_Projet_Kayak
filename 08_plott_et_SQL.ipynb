# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/maurice/Documents/certification/bloc_1_Build_and_manage_a_data_infrastructure/csv_files/final_villes_hotels_meteo.csv')

# %%
data
# Out:
#     date_arrivee date_depart  id_destination  id_hotel  destination_x  \
# 0     04-01-2025  10-01-2025               0         1  Aigues Mortes
# 1     04-01-2025  10-01-2025               0         2  Aigues Mortes
# 2     04-01-2025  10-01-2025               0         3  Aigues Mortes
# 3     04-01-2025  10-01-2025               0         4  Aigues Mortes
# 4     04-01-2025  10-01-2025               0         5  Aigues Mortes
# ..           ...         ...             ...       ...            ...
# 837   04-01-2025  10-01-2025              34       838           Uzes
# 838   04-01-2025  10-01-2025              34       839           Uzes
# 839   04-01-2025  10-01-2025              34       840           Uzes
# 840   04-01-2025  10-01-2025              34       841           Uzes
# 841   04-01-2025  10-01-2025              34       842           Uzes
#
#                                   name  price  \
# 0           Ibis Lunel Petite Camargue    497
# ...
